# %%
import codecs
import re
import numpy as np
import pymysql
from snownlp import SnowNLP
import matplotlib.pyplot as plt
from snownlp import sentiment
from snownlp.sentiment import Sentiment

comment = []
with open('msg.txt', mode='r') as f:
    rows = f.readlines()
    for row in rows:
        if len(row)==0:
            print row
            continue
        if row not in comment:
            comment.append(row.strip('\n'))

# %%
def snowanalysis(self):
    sentimentslist = []
    for li in self:
        print(li)
        s = SnowNLP(li)
        print(s.sentiments)
        sentimentslist.append(s.sentiments)
    plt.hist(sentimentslist, bins=np.arange(0, 1, 0.01))
    plt.show()
    snowanalysis(comment)
# Out:
# 和
# 0.5
# 联保卡怎么激活？
# 0.5
# 我是客户经理。能不能在手机位置区域锁定门店，看不到其他区域的微店
# 0.5
# 我看的就这一款/:wipe
# 0.5
# 忙不
# 0.5
# /::)
# 0.5
# 你好
# 0.5
# 我发信息是发给公司还是导购本人呢
# 0.5
# 有便宜的吗？
# 0.5
# 习水商家报修
# 0.5
# /::)
# 0.5
# /:--b/::)
# 0.5
# 你好
# 0.5
# 嗯
# 0.5
# 好
# 0.5
# 明天有空看
# 0.5
# 没有
# 0.5
# 看了两款
# 0.5
# 奖品怎么领
# 0.5
# 亲
# 0.5
# 你们的书桌材质是什么
# 0.5
# 让人心疼放心不下
# 0.5
# 老姐/::|/::|/::|/:
# 0.5
# 防盗门高240
# 0.5
# 我之前在网上看到你们宣传免费送藤椅的活动
# 0.5
# 包含床头柜么？
# 0.5
# 夏天睡硬的一面，冬天睡软的哪面
# 0.5
# 算了，我们在外面有你那么多钱就好了！
# 0.5
# 啥活动
# 0.5
# 你好
# 0.5
# /::)
# 0.5
# 坏的
# 0.5
# 不好意思，点错了
# 0.5
# 我发了那么多，你看不见吗
# 0.5
# 买家具
# 0.5
# 他说产地在成都，在成都买要便宜点
# 0.5
# 你们在撒时候有活动
# 0.5
# 做能打开的吧
# 0.5
# 那是骗子吗/::</::</::<
# 0.5
# 不用，可气了
# 0.5
# 哈哈哈，得让老王请客！哈哈哈，我去的话得十号了吧，8号活动结束，9号返程坐车，十号就没事了
# 0.5
# 行
# 0.5
# 好的
# 0.5
# 这不成了一个聊天工具了吗
# 0.5
# 或者你姐买
# 0.5
# 哦，好的
# 0.5
# 我不是在你家截得图
# 0.5
# 东原时光道
# 0.5
# 好的
# 0.5
# 我们之前选到那里的东西可能要换哈，现在装修有些可能不搭配了
# 0.5
# 快快回答我
# 0.5
# 咨询过京东商城的旗舰店客服了，但是没有具体说清楚
# 0.5
# 在吗
# 0.5
# 哦
# 0.5
# 紧就点
# 0.5
# /::)
# 0.5
# 呵呵呵
# 0.5
# /:strong/:strong/:strong
# 0.5
# 你忙吧，我只是随便看看
# 0.5
# 你好
# 0.5
# 鲜颜点的
# 0.5
# /:coffee
# 0.5
# 又没找你
# 0.5
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-6-52a6e2b420f1> in <module>()
# ----> 1 snowanalysis(comment)
#
# <ipython-input-5-4ea3c7910f09> in snowanalysis(self)
#      20     for li in self:
#      21         print(li)
# ---> 22         s = SnowNLP(li)
#      23         print(s.sentiments)
#      24         sentimentslist.append(s.sentiments)
#
# d:\python27\lib\site-packages\snownlp\__init__.pyc in __init__(self, doc)
#      15     def __init__(self, doc):
#      16         self.doc = doc
# ---> 17         self.bm25 = bm25.BM25(doc)
#      18
#      19     @property
#
# d:\python27\lib\site-packages\snownlp\sim\bm25.pyc in __init__(self, docs)
#       9     def __init__(self, docs):
#      10         self.D = len(docs)
# ---> 11         self.avgdl = sum([len(doc)+0.0 for doc in docs]) / self.D
#      12         self.docs = docs
#      13         self.f = []
#
# ZeroDivisionError: integer division or modulo by zero
